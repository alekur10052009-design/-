# %%
import pygame
pygame.init()
font = pygame.font.SysFont(None, 24)

screen = pygame.display.set_mode((690, 1000))
pygame.display.set_caption("шняга")

running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    
    screen.fill((255,255,255))
    #асфальт
    pygame.draw.rect(screen, (83,108,103), (0,571,707,449)) 
    #задний фон
    pygame.draw.rect(screen, (183,196,200), (0,0,707,563))
    #странный эллипс на земле
    pygame.draw.ellipse(screen, (183,200,196), (-10, 810, 830, 320)) 
    #выхлопная труба
    pygame.draw.ellipse(screen, (0,34,43), (250,855,50,10))
    #кузов
    pygame.draw.rect(screen, (0,204,255), (270,825,315,50))
    #колёса
    pygame.draw.ellipse(screen, (0,34,43), (293,850,70,50))
    pygame.draw.ellipse(screen, (0,34,43), (493,850,70,50))
    #верх кузова
    pygame.draw.rect(screen, (0,204,255), (330,790,135,40))
    #окна
    pygame.draw.rect(screen, (213,246,255), (340,800,50,25))
    pygame.draw.rect(screen, (213,246,255), (413,797,43,25))
    #типо лужи
    s = pygame.Surface((707, 1000), pygame.SRCALPHA)
    pygame.draw.ellipse(s, (108,133,128, 100), (25,825,200,50))
    pygame.draw.ellipse(s, (108,133,128, 220), (22,755,204,50))
    pygame.draw.ellipse(s, (108,133,128, 220), (-100,685,200,50))
    screen.blit(s, (0,0))
    #заднее облако сверху
    s = pygame.Surface((707, 1000), pygame.SRCALPHA)
    pygame.draw.ellipse(s, (108,133,128, 60), (-60, 43, 550, 150))
    screen.blit(s, (0,0))
    #заднее облако снизу
    s = pygame.Surface((707, 1000), pygame.SRCALPHA)
    pygame.draw.ellipse(s, (108,133,128, 60), (-100, 380, 500, 160))
    screen.blit(s, (0,0))
    #небоскрёб 1
    pygame.draw.rect(screen, (147,169,170), (11,15,150,585))
    #небоскрёб 5
    pygame.draw.rect(screen, (219,227,226), (500,14,155,590))
    #облако между 3 и 5
    s = pygame.Surface((707, 1000), pygame.SRCALPHA)
    pygame.draw.ellipse(s, (108,133,128, 60), (200, -30, 800, 160))
    screen.blit(s, (0,0))
    #небоскрёб 3
    pygame.draw.rect(screen, (147,172,167), (180,45,155,570))
    #небоскрёб 2
    pygame.draw.rect(screen, (183,200,196), (120,130,160,575))
    #небоскрёб 4
    pygame.draw.rect(screen, (111,145,138), (470,163,150,557))
    #переднее облако
    s = pygame.Surface((707, 1000), pygame.SRCALPHA)
    pygame.draw.ellipse(s, (108,133,128, 60), (160, 250, 650, 160))
    screen.blit(s, (0,0))


    mx, my = pygame.mouse.get_pos()
    text = font.render(f"x: {mx}, y: {my}", True, (0, 0, 0))
    screen.blit(text, (10, 10))

    pygame.display.flip()
    

pygame.quit()
